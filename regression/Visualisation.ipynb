# %%
# %matplotlib inline
import numpy as np
import matplotlib.pylab as plt

# %%
X = np.load('Data/X.npy')
X = X[:,1:]
y = np.load('Data/y.npy')
test_in = np.load('Data/reg_test_in.npy')

# %%
test_in.shape
# Out:
# (2250, 14)

# %%
plt.plot(X[:,13],y, marker = 'o')

# %%
plt.plot(X[:,13],y, marker = 'o')

# %%
plt.plot(X[:,1])

# %%
plt.scatter(range(test_in.shape[0]),test_in[:,1])

# %%
for i in range(14):
    column = test_in[:,i]
    x = column[~np.isnan(column)]
    mean = np.mean(x)
    var = np.var(x)
    #print mean, var
    for j in range(len(column)):
        if np.isnan(column[j]):
            print test_in[j,i]
            #print np.random.normal(mean,var)
            test_in[j,i] = np.random.normal(mean,var)

# %%
plt.plot(test_in[:,4])

# %%
plt.plot(test_in[:,4])

# %%
plt.plot(y)

# %%
X
# Out:
# array([[  0.00000000e+00,  -9.12900000e-01,  -7.68700000e-01, ...,
#          -7.84400000e-01,  -7.24100000e-01,  -8.25500000e-01],
#        [  2.08300000e-01,  -1.02740000e+00,  -7.68700000e-01, ...,
#          -7.84400000e-01,  -7.79700000e-01,  -9.36900000e-01],
#        [  4.16700000e-01,  -1.08470000e+00,  -8.28300000e-01, ...,
#          -8.97600000e-01,  -9.46400000e-01,  -1.10400000e+00],
#        ...,
#        [  7.77937500e+03,   1.75000000e-01,   5.43800000e-01, ...,
#           2.90900000e-01,   3.87300000e-01,   2.32400000e-01],
#        [  7.77958330e+03,   1.17700000e-01,   5.43800000e-01, ...,
#           3.47500000e-01,   3.31700000e-01,   2.32400000e-01],
#        [  7.77979170e+03,   6.04000000e-02,   3.64800000e-01, ...,
#           2.34300000e-01,   2.76100000e-01,   1.76700000e-01]])
